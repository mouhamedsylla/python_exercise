# %%
from geopy.geocoders import Nominatim
#from geopy import distance
import folium
import webbrowser
"""region = ["Dakar",
          "Thies",
          "Diourbel",
          "Kaolack",
          "Fatick",
          "Kaffrine",
          "Louga",
          "Saint-Lious",
          "Matam",
          "Tambacounda",
          "Kédougou",
          "Kolda",
          "Ziguinchor",
          "Sédhiou",

]"""
city_liaison = [["Dakar", "Pikine", "Guediawaye", "Rufisque", "Keur Massar"],
                ["Thies", "Mbour", "Tivaoune"],
                ["Diourbel", "Bambey", "Mbacké"],
                ["Fatick", "Foundiougne","Gossas"],
                ["Kaolack", "Guingueneo", "Nioro Du Rip"],
                ["Kaffrine", "Birkelane", "Malem Hodar", "Koungheul"],
                ["Louga", "Kébémer"],
                ["Saint-Louis", "Dagana", "Podor"],
                ["Matam", "Kanel", "Ranerou"],
                ["Tambacounda", "Koumpentoum", "Goudiry", "Bakel"],
                ["Kédougou", "Sareya", "Salemata"],
                ["Kolda", "Vélingara", "Medina Yoro Foula"],
                ["Ziguinchor", "Oussouye", "Bignona",],  
                ["Sédhiou", "Goudomp", "Bounkiling"],

]
# On range les régions dans un listes nommé region
region = []
for i in range(0, len(city_liaison)):
    region += [city_liaison[i][0]]
# On recupére les coordonnées des régions
geolocator = Nominatim(user_agent="Microsoft Edge")
Coord = []
for i in region:
    location = geolocator.geocode(i)
    Coord += [[location.latitude, location.longitude]]
"""print(i, "a pour coordonnée :", Coord)
    print()
    print()
    print("------------------------------------------------------------------------------")
    print()"""
# Calcul de distance entre deux villes avec le module distance de geopy
"""
dakar = geolocator.geocode(region[0])
sedhiou = geolocator.geocode(region[13])
ville1 = (dakar.latitude, dakar.longitude)
ville2 = (sedhiou.latitude, sedhiou.longitude)
print("*************************************************************************")
print()
print(distance.distance(ville1, ville2).km)

"""

#Création de ma carte
my_map = folium.Map(location=[14.814349, -17.249890], zoom_start=5)
k=0
# Déssiner le graphe avec les coordonnées des régions
for each in Coord:
    folium.RegularPolygonMarker(location=each,popup=region[k],
                                fill_color='blue',
                                number_of_sides=10,
                                radius=10).add_to(my_map)
    k+=1

# Nous allons maintenant implémenter les différents liaisons dans notre carte

for i in city_liaison:
    #from geopy.geocoders import Nominatim
    geolocator = Nominatim(user_agent="Microsoft Edge")
    Coordonnees=[]
    location = geolocator.geocode(i[0])
    Coordonnees += [[location.latitude, location.longitude]]
    print(i, "a pour coordonnée :", Coordonnees)
    print()
    for k in range(0,len(city_liaison[i])):
        #from geopy.geocoders import Nominatim
        geolocator = Nominatim(user_agent="Microsoft Edge")
        location = geolocator.geocode(city_liaison[i][k])
        Coordonnees += [[location.latitude, location.longitude]]
        folium.PolyLine(Coordonnees, color="green", weight=2.5, opacity=1).add_to(my_map)
        Coordonnees = [Coordonnees[0]]

my_map.save("C:\\Users\\HP\\Documents\\code_python\\macarte1.html")
url = 'C:\\Users\\HP\\Documents\\code_python\\macarte1.html'
webbrowser.open_new_tab(url)
# Out:
# ['Dakar', 'Pikine', 'Guediawaye', 'Rufisque', 'Keur Massar'] a pour coordonnée : [[14.693425, -17.447938]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14204/2364436145.py in <module>
#      83     print(i, "a pour coordonnée :", Coordonnees)
#      84     print()
# ---> 85     for k in range(0,len(city_liaison[i])):
#      86         #from geopy.geocoders import Nominatim
#      87         geolocator = Nominatim(user_agent="Microsoft Edge")
#
# TypeError: list indices must be integers or slices, not list

# %%
from geopy.geocoders import Nominatim
#from geopy import distance
import folium
import webbrowser
"""region = ["Dakar",
          "Thies",
          "Diourbel",
          "Kaolack",
          "Fatick",
          "Kaffrine",
          "Louga",
          "Saint-Lious",
          "Matam",
          "Tambacounda",
          "Kédougou",
          "Kolda",
          "Ziguinchor",
          "Sédhiou",

]"""
city_liaison = [["Dakar", "Pikine", "Guediawaye", "Rufisque", "Keur Massar"],
                ["Thies", "Mbour", "Tivaoune"],
                ["Diourbel", "Bambey", "Mbacké"],
                ["Fatick", "Foundiougne","Gossas"],
                ["Kaolack", "Guingueneo", "Nioro Du Rip"],
                ["Kaffrine", "Birkelane", "Malem Hodar", "Koungheul"],
                ["Louga", "Kébémer"],
                ["Saint-Louis", "Dagana", "Podor"],
                ["Matam", "Kanel", "Ranerou"],
                ["Tambacounda", "Koumpentoum", "Goudiry", "Bakel"],
                ["Kédougou", "Sareya", "Salemata"],
                ["Kolda", "Vélingara", "Medina Yoro Foula"],
                ["Ziguinchor", "Oussouye", "Bignona",],  
                ["Sédhiou", "Goudomp", "Bounkiling"],

]
# On range les régions dans un listes nommé region
region = []
for i in range(0, len(city_liaison)):
    region += [city_liaison[i][0]]
# On recupére les coordonnées des régions
geolocator = Nominatim(user_agent="Microsoft Edge")
Coord = []
for i in region:
    location = geolocator.geocode(i)
    Coord += [[location.latitude, location.longitude]]
"""print(i, "a pour coordonnée :", Coord)
    print()
    print()
    print("------------------------------------------------------------------------------")
    print()"""
# Calcul de distance entre deux villes avec le module distance de geopy
"""
dakar = geolocator.geocode(region[0])
sedhiou = geolocator.geocode(region[13])
ville1 = (dakar.latitude, dakar.longitude)
ville2 = (sedhiou.latitude, sedhiou.longitude)
print("*************************************************************************")
print()
print(distance.distance(ville1, ville2).km)

"""

#Création de ma carte
my_map = folium.Map(location=[14.814349, -17.249890], zoom_start=5)
k=0
# Déssiner le graphe avec les coordonnées des régions
for each in Coord:
    folium.RegularPolygonMarker(location=each,popup=region[k],
                                fill_color='blue',
                                number_of_sides=10,
                                radius=10).add_to(my_map)
    k+=1

# Nous allons maintenant implémenter les différents liaisons dans notre carte

for i in city_liaison:
    #from geopy.geocoders import Nominatim
    geolocator = Nominatim(user_agent="Microsoft Edge")
    Coordonnees=[]
    location = geolocator.geocode(i[0])
    Coordonnees += [[location.latitude, location.longitude]]
    print(i, "a pour coordonnée :", Coordonnees)
    print()
    for k in city_liaison:
        #from geopy.geocoders import Nominatim
        geolocator = Nominatim(user_agent="Microsoft Edge")
        location = geolocator.geocode(city_liaison[i][k])
        Coordonnees += [[location.latitude, location.longitude]]
        folium.PolyLine(Coordonnees, color="green", weight=2.5, opacity=1).add_to(my_map)
        Coordonnees = [Coordonnees[0]]

my_map.save("C:\\Users\\HP\\Documents\\code_python\\macarte1.html")
url = 'C:\\Users\\HP\\Documents\\code_python\\macarte1.html'
webbrowser.open_new_tab(url)
# Out:
# ['Dakar', 'Pikine', 'Guediawaye', 'Rufisque', 'Keur Massar'] a pour coordonnée : [[14.693425, -17.447938]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14204/3060598108.py in <module>
#      86         #from geopy.geocoders import Nominatim
#      87         geolocator = Nominatim(user_agent="Microsoft Edge")
# ---> 88         location = geolocator.geocode(city_liaison[i][k])
#      89         Coordonnees += [[location.latitude, location.longitude]]
#      90         folium.PolyLine(Coordonnees, color="green", weight=2.5, opacity=1).add_to(my_map)
#
# TypeError: list indices must be integers or slices, not list

# %%
from geopy.geocoders import Nominatim
#from geopy import distance
import folium
import webbrowser
"""region = ["Dakar",
          "Thies",
          "Diourbel",
          "Kaolack",
          "Fatick",
          "Kaffrine",
          "Louga",
          "Saint-Lious",
          "Matam",
          "Tambacounda",
          "Kédougou",
          "Kolda",
          "Ziguinchor",
          "Sédhiou",

]"""
city_liaison = [["Dakar", "Pikine", "Guediawaye", "Rufisque", "Keur Massar"],
                ["Thies", "Mbour", "Tivaoune"],
                ["Diourbel", "Bambey", "Mbacké"],
                ["Fatick", "Foundiougne","Gossas"],
                ["Kaolack", "Guingueneo", "Nioro Du Rip"],
                ["Kaffrine", "Birkelane", "Malem Hodar", "Koungheul"],
                ["Louga", "Kébémer"],
                ["Saint-Louis", "Dagana", "Podor"],
                ["Matam", "Kanel", "Ranerou"],
                ["Tambacounda", "Koumpentoum", "Goudiry", "Bakel"],
                ["Kédougou", "Sareya", "Salemata"],
                ["Kolda", "Vélingara", "Medina Yoro Foula"],
                ["Ziguinchor", "Oussouye", "Bignona",],  
                ["Sédhiou", "Goudomp", "Bounkiling"],

]
# On range les régions dans un listes nommé region
region = []
for i in range(0, len(city_liaison)):
    region += [city_liaison[i][0]]
# On recupére les coordonnées des régions
geolocator = Nominatim(user_agent="Microsoft Edge")
Coord = []
for i in region:
    location = geolocator.geocode(i)
    Coord += [[location.latitude, location.longitude]]
"""print(i, "a pour coordonnée :", Coord)
    print()
    print()
    print("------------------------------------------------------------------------------")
    print()"""
# Calcul de distance entre deux villes avec le module distance de geopy
"""
dakar = geolocator.geocode(region[0])
sedhiou = geolocator.geocode(region[13])
ville1 = (dakar.latitude, dakar.longitude)
ville2 = (sedhiou.latitude, sedhiou.longitude)
print("*************************************************************************")
print()
print(distance.distance(ville1, ville2).km)

"""

#Création de ma carte
my_map = folium.Map(location=[14.814349, -17.249890], zoom_start=5)
k=0
# Déssiner le graphe avec les coordonnées des régions
for each in Coord:
    folium.RegularPolygonMarker(location=each,popup=region[k],
                                fill_color='blue',
                                number_of_sides=10,
                                radius=10).add_to(my_map)
    k+=1

# Nous allons maintenant implémenter les différents liaisons dans notre carte

for i in city_liaison:
    #from geopy.geocoders import Nominatim
    geolocator = Nominatim(user_agent="Microsoft Edge")
    Coordonnees=[]
    location = geolocator.geocode(i[0])
    Coordonnees += [[location.latitude, location.longitude]]
    print(i, "a pour coordonnée :", Coordonnees)
    print()
    j=0
    for k in city_liaison:
        #from geopy.geocoders import Nominatim
        geolocator = Nominatim(user_agent="Microsoft Edge")
        location = geolocator.geocode(k[j])
        Coordonnees += [[location.latitude, location.longitude]]
        folium.PolyLine(Coordonnees, color="green", weight=2.5, opacity=1).add_to(my_map)
        Coordonnees = [Coordonnees[0]]
        j += 1

my_map.save("C:\\Users\\HP\\Documents\\code_python\\macarte1.html")
url = 'C:\\Users\\HP\\Documents\\code_python\\macarte1.html'
webbrowser.open_new_tab(url)
# Out:
# ['Dakar', 'Pikine', 'Guediawaye', 'Rufisque', 'Keur Massar'] a pour coordonnée : [[14.693425, -17.447938]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14204/577901249.py in <module>
#      87         #from geopy.geocoders import Nominatim
#      88         geolocator = Nominatim(user_agent="Microsoft Edge")
# ---> 89         location = geolocator.geocode(k[j])
#      90         Coordonnees += [[location.latitude, location.longitude]]
#      91         folium.PolyLine(Coordonnees, color="green", weight=2.5, opacity=1).add_to(my_map)
#
# IndexError: list index out of range

# %%
from geopy.geocoders import Nominatim
#from geopy import distance
import folium
import webbrowser
"""region = ["Dakar",
          "Thies",
          "Diourbel",
          "Kaolack",
          "Fatick",
          "Kaffrine",
          "Louga",
          "Saint-Lious",
          "Matam",
          "Tambacounda",
          "Kédougou",
          "Kolda",
          "Ziguinchor",
          "Sédhiou",

]"""
city_liaison = [["Dakar", "Pikine", "Guediawaye", "Rufisque", "Keur Massar"],
                ["Thies", "Mbour", "Tivaoune"],
                ["Diourbel", "Bambey", "Mbacké"],
                ["Fatick", "Foundiougne","Gossas"],
                ["Kaolack", "Guingueneo", "Nioro Du Rip"],
                ["Kaffrine", "Birkelane", "Malem Hodar", "Koungheul"],
                ["Louga", "Kébémer"],
                ["Saint-Louis", "Dagana", "Podor"],
                ["Matam", "Kanel", "Ranerou"],
                ["Tambacounda", "Koumpentoum", "Goudiry", "Bakel"],
                ["Kédougou", "Sareya", "Salemata"],
                ["Kolda", "Vélingara", "Medina Yoro Foula"],
                ["Ziguinchor", "Oussouye", "Bignona",],  
                ["Sédhiou", "Goudomp", "Bounkiling"],

]
# On range les régions dans un listes nommé region
region = []
for i in range(0, len(city_liaison)):
    region += [city_liaison[i][0]]
# On recupére les coordonnées des régions
geolocator = Nominatim(user_agent="Microsoft Edge")
Coord = []
for i in region:
    location = geolocator.geocode(i)
    Coord += [[location.latitude, location.longitude]]
"""print(i, "a pour coordonnée :", Coord)
    print()
    print()
    print("------------------------------------------------------------------------------")
    print()"""
# Calcul de distance entre deux villes avec le module distance de geopy
"""
dakar = geolocator.geocode(region[0])
sedhiou = geolocator.geocode(region[13])
ville1 = (dakar.latitude, dakar.longitude)
ville2 = (sedhiou.latitude, sedhiou.longitude)
print("*************************************************************************")
print()
print(distance.distance(ville1, ville2).km)

"""

#Création de ma carte
my_map = folium.Map(location=[14.814349, -17.249890], zoom_start=5)
k=0
# Déssiner le graphe avec les coordonnées des régions
for each in Coord:
    folium.RegularPolygonMarker(location=each,popup=region[k],
                                fill_color='blue',
                                number_of_sides=10,
                                radius=10).add_to(my_map)
    k+=1

# Nous allons maintenant implémenter les différents liaisons dans notre carte

for i in city_liaison:
    #from geopy.geocoders import Nominatim
    geolocator = Nominatim(user_agent="Microsoft Edge")
    Coordonnees=[]
    location = geolocator.geocode(i[0])
    Coordonnees += [[location.latitude, location.longitude]]
    folium.PolyLine(Coordonnees, color="green", weight=2.5, opacity=1).add_to(my_map)
    """j=0
    for k in city_liaison:
        #from geopy.geocoders import Nominatim
        geolocator = Nominatim(user_agent="Microsoft Edge")
        location = geolocator.geocode(k[j])
        Coordonnees += [[location.latitude, location.longitude]]
        folium.PolyLine(Coordonnees, color="green", weight=2.5, opacity=1).add_to(my_map)
        Coordonnees = [Coordonnees[0]]
        j += 1"""

my_map.save("C:\\Users\\HP\\Documents\\code_python\\macarte1.html")
url = 'C:\\Users\\HP\\Documents\\code_python\\macarte1.html'
webbrowser.open_new_tab(url)
# Out:
# True

# %%
from geopy.geocoders import Nominatim
#from geopy import distance
import folium
import webbrowser
"""region = ["Dakar",
          "Thies",
          "Diourbel",
          "Kaolack",
          "Fatick",
          "Kaffrine",
          "Louga",
          "Saint-Lious",
          "Matam",
          "Tambacounda",
          "Kédougou",
          "Kolda",
          "Ziguinchor",
          "Sédhiou",

]"""
city_liaison = [["Dakar", "Pikine", "Guediawaye", "Rufisque", "Keur Massar"],
                ["Thies", "Mbour", "Tivaoune"],
                ["Diourbel", "Bambey", "Mbacké"],
                ["Fatick", "Foundiougne","Gossas"],
                ["Kaolack", "Guingueneo", "Nioro Du Rip"],
                ["Kaffrine", "Birkelane", "Malem Hodar", "Koungheul"],
                ["Louga", "Kébémer"],
                ["Saint-Louis", "Dagana", "Podor"],
                ["Matam", "Kanel", "Ranerou"],
                ["Tambacounda", "Koumpentoum", "Goudiry", "Bakel"],
                ["Kédougou", "Sareya", "Salemata"],
                ["Kolda", "Vélingara", "Medina Yoro Foula"],
                ["Ziguinchor", "Oussouye", "Bignona",],  
                ["Sédhiou", "Goudomp", "Bounkiling"],

]
# On range les régions dans un listes nommé region
region = []
for i in range(0, len(city_liaison)):
    region += [city_liaison[i][0]]
# On recupére les coordonnées des régions
geolocator = Nominatim(user_agent="Microsoft Edge")
Coord = []
for i in region:
    location = geolocator.geocode(i)
    Coord += [[location.latitude, location.longitude]]
"""print(i, "a pour coordonnée :", Coord)
    print()
    print()
    print("------------------------------------------------------------------------------")
    print()"""
# Calcul de distance entre deux villes avec le module distance de geopy
"""
dakar = geolocator.geocode(region[0])
sedhiou = geolocator.geocode(region[13])
ville1 = (dakar.latitude, dakar.longitude)
ville2 = (sedhiou.latitude, sedhiou.longitude)
print("*************************************************************************")
print()
print(distance.distance(ville1, ville2).km)

"""

#Création de ma carte
my_map = folium.Map(location=[14.814349, -17.249890], zoom_start=5)
k=0
# Déssiner le graphe avec les coordonnées des régions
for each in Coord:
    folium.RegularPolygonMarker(location=each,popup=region[k],
                                fill_color='blue',
                                number_of_sides=10,
                                radius=10).add_to(my_map)
    k+=1

# Nous allons maintenant implémenter les différents liaisons dans notre carte

for i in city_liaison:
    #from geopy.geocoders import Nominatim
    geolocator = Nominatim(user_agent="Microsoft Edge")
    Coordonnees=[]
    location = geolocator.geocode(i[0])
    Coordonnees += [[location.latitude, location.longitude]]
    folium.PolyLine(Coordonnees, color="green", weight=2.5, opacity=1).add_to(my_map)
    Coordonnees = [Coordonnees[0]]
    """j=0
    for k in city_liaison:
        #from geopy.geocoders import Nominatim
        geolocator = Nominatim(user_agent="Microsoft Edge")
        location = geolocator.geocode(k[j])
        Coordonnees += [[location.latitude, location.longitude]]
        folium.PolyLine(Coordonnees, color="green", weight=2.5, opacity=1).add_to(my_map)
        Coordonnees = [Coordonnees[0]]
        j += 1"""

my_map.save("C:\\Users\\HP\\Documents\\code_python\\macarte1.html")
url = 'C:\\Users\\HP\\Documents\\code_python\\macarte1.html'
webbrowser.open_new_tab(url)
# Out:
# True
